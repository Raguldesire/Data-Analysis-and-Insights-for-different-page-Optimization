# %% [markdown]
# # **Problem statement**

# %% [markdown]
# As an intern in the Business Analytics team, your task is to analyze a provided dataset and generate actionable insights to optimize page performance for a fictional company called "XYZ Inc." The dataset contains user data from various regions, customer demographics, product information, and marketing campaign details. Your objective is to identify critical factors influencing Data Analysis and Insights for different page Optimization and how to get more user installation and engagement from the App and website" User and propose recommendations for improving performance.
# Assignment:

# %%
#Required Libary
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# #User acquistion XLSX
#
# # **Data Analysis**
# In this file we have user acquistion data about the engagement of users.

# %%
Aquistion = pd.read_excel('/content/user acquistion.XLSX')
Aquistion
# Out:
#   First user default channel group  New users  Engaged sessions  \
# 0                          Display       9957             12008
# 1                   Organic Search       7652             18141
# 2                      Paid Search       3025              4408
# 3                           Direct       1903              4975
# 4                       Unassigned        325              1619
# 5                   Organic Social         10                13
#
#    Engagement rate  Engaged sessions per user  Average engagement time  \
# 0         0.544457                   1.206107                 58.86209
# 1         0.813680                   2.367041                534.31280
# 2         0.474284                   1.458154                102.23780
# 3         0.318808                   2.261364               1128.88100
# 4         0.813159                   4.981538                798.34150
# 5         0.722222                   1.300000                145.30000
#
# ...

# %%
#Collecting Data from google drive
#getting data
Traffic = pd.read_excel("/content/Talent Acquis.xlsx")
Event = pd.read_excel("/content/Event report.xlsx")
Conversion = pd.read_excel("/content/Conversion report.xlsx")
Page_screen = pd.read_excel("/content/Page and screen report.xlsx")
Demographic = pd.read_excel("/content/Demographic report.xlsx")
Citiwise  = pd.read_excel("/content/citiwise report.xlsx")
Gender = pd.read_excel("/content/Gender report.xlsx")
Used_by_interest = pd.read_excel("/content/user by interest.xlsx")
Language = pd.read_excel("/content/user by language.xlsx")
Use_by_age = pd.read_excel("/content/user by age.xlsx")
Google_ads = pd.read_excel("/content/Google-ads.xlsx")

# %% [markdown]
# # **Preprocessing**

# %% [markdown]
# **Checking missing values and data formats**

# %%
Aquistion.isnull().sum()
# Out:
# First user default channel group    0
# New users                           0
# Engaged sessions                    0
# Engagement rate                     0
# Engaged sessions per user           0
# Average engagement time             0
# Event count                         0
# Conversions                         0
# Total revenue                       0
# dtype: int64

# %%
Aquistion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   First user default channel group  6 non-null      object
#  1   New users                         6 non-null      int64
#  2   Engaged sessions                  6 non-null      int64
#  3   Engagement rate                   6 non-null      float64
#  4   Engaged sessions per user         6 non-null      float64
#  5   Average engagement time           6 non-null      float64
#  6   Event count                       6 non-null      int64
#  7   Conversions                       6 non-null      int64
#  8   Total revenue                     6 non-null      int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 560.0+ bytes

# %% [markdown]
# Exploratory data analysis to understand the dataset and to identify outliers and missing values.

# %%
#EDA Insights of user acqusition
import plotly.graph_objects as go
acq = go.Pie(labels=Aquistion["First user default channel group"],
                     values=Aquistion["New users"],
                     textinfo='label+percent',
                     textposition='outside',
                     hoverinfo='label+percent',
                     hole=0.5)
layout = go.Layout(title='User Acquisition')

fig = go.Figure(data=[acq], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
Aquistion.columns
# Out:
# Index(['First user default channel group', 'New users', 'Engaged sessions',
#        'Engagement rate', 'Engaged sessions per user',
#        'Average engagement time', 'Event count', 'Conversions',
#        'Total revenue'],
#       dtype='object')

# %% [markdown]
# # Outliers-
# An outlier is a data point that differs significantly from other observations. An outlier may be due to a variability in the measurement, an indication of novel data, or it may be the result of experimental error; the latter are sometimes excluded from the data set.

# %%
# #outliers
# def visuals(columns):
#   for i in columns:
#     sn.histplot(data=Aquistion,x=i,color='g',kde=True)
#     plt.title(f'Outliers in {i}')
#     plt.show()
#     print()
#     print()

# visuals = (['First user default channel group', 'New users', 'Engaged sessions','Engagement rate', 'Engaged sessions per user',
#      'Average engagement time', 'Event count', 'Conversions','Total revenue'])

# %%
#Outliers
def visuals(columns):
    for i in columns:
        sn.histplot(data=Aquistion, x=i, color='g', kde=True)
        plt.title(f'Outliers in {i}')
        plt.show()
        print()
        print()

columns_to_visualize = ['New users', 'Engaged sessions',
                        'Engagement rate', 'Engaged sessions per user', 'Average engagement time',
                        'Event count', 'Conversions']

visuals(columns_to_visualize)

# %% [markdown]
# # Correlation
# Correlation is used to test relationships between quantitative variables or categorical variables. In other words, it’s a measure of how things are related.

# %%
#correlation
plt.figure(figsize=(10,8))
x = Aquistion [['New users', 'Engaged sessions','Engagement rate', 'Engaged sessions per user','Average engagement time',
                'Event count', 'Conversions']]
sn.heatmap(x.corr(),annot=True)
plt.show()

# %% [markdown]
# # Traffic Report
# In this file we have traffic data about the company.

# %%
#2
Traffic
# Out:
#   Session default channel group  Users  Sessions  Engaged sessions  \
# 0                    Unassigned  20263     13448              1481
# 1                       Display   9613     18292             10613
# 2                Organic Search   7689     21241             17814
# 3                        Direct   4042     13220              7649
# 4                   Paid Search   2909      6788              3452
# 5                Organic Social     11        16                12
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                             34.11704                   0.073089
# 1                             28.52198                   1.104026
# 2                            195.94340                   2.316816
# 3                            177.17060                   1.892380
# 4                             36.65321                   1.186662
# 5                             60.06250                   1.090909
#
# ...

# %%
Traffic.isnull().sum()
# Out:
# Session default channel group          0
# Users                                  0
# Sessions                               0
# Engaged sessions                       0
# Average engagement time per session    0
# Engaged sessions per user              0
# Events per session                     0
# Engagement rate                        0
# Event count                            0
# Conversions                            0
# Total revenue                          0
# dtype: int64

# %%
Traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Session default channel group        6 non-null      object
#  1   Users                                6 non-null      int64
#  2   Sessions                             6 non-null      int64
#  3   Engaged sessions                     6 non-null      int64
#  4   Average engagement time per session  6 non-null      float64
#  5   Engaged sessions per user            6 non-null      float64
#  6   Events per session                   6 non-null      float64
#  7   Engagement rate                      6 non-null      float64
#  8   Event count                          6 non-null      int64
#  9   Conversions                          6 non-null      int64
#  10  Total revenue                        6 non-null      int64
# ...

# %%
#EDA
Tra = go.Pie(labels=Traffic["Session default channel group"],
                     values=Traffic["Users"],
                     textinfo='label+percent',
                     textposition='outside',
                     hoverinfo='label+percent',
                     hole=0.5)
layout = go.Layout(title='Traffic')

fig = go.Figure(data=[Tra], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def visuals(columns):
  for i in columns:
    sn.histplot(data=Traffic, x=i, color='g', kde=True)
    plt.title(f'Outliers in {i}')
    plt.show()
    print()
    print()
columns_to_visualize = ['Users', 'Sessions','Engaged sessions', 'Average engagement time per session',
       'Engaged sessions per user', 'Events per session', 'Engagement rate',
       'Event count', 'Conversions']
visuals(columns_to_visualize)

# %% [markdown]
# # Event Report
# Event report is the number of events that occur during a certain period of time.

# %%
#3
Event.head(10)
# Out:
#    Event name  Event count  Total users  Event count per user  Total revenue
# 0  Event name       694729        23254             30.865870              0
# 1  Event name       125146         1700            138.896800              0
# 2  Event name       124836        22699              5.622230              0
# 3  Event name        70128         1369            144.000000              0
# 4  Event name        61163        23226              3.121357              0
# 5  Event name        22872        23059              0.991890              0
# 6  Event name        18080        18030              4.037517              0
# 7  Event name        12719         6174              2.068803              0
# 8  Event name         7942         1837              4.323353              0
# 9  Event name         7449         3517              2.130721              0

# %%
Event.isnull().sum()
# Out:
# Event name              1
# Event count             0
# Total users             0
# Event count per user    0
# Total revenue           0
# dtype: int64

# %%
Event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Event name            378 non-null    object
#  1   Event count           379 non-null    int64
#  2   Total users           379 non-null    int64
#  3   Event count per user  379 non-null    float64
#  4   Total revenue         379 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 14.9+ KB

# %%
Event = Event.dropna()

# %%
#checking again missing value
Event.isnull().sum()
# Out:
# Event name              0
# Event count             0
# Total users             0
# Event count per user    0
# Total revenue           0
# dtype: int64

# %% [markdown]
# # Trend of Event
# Trend analysis quantifies and explains trends and patterns in a “noisy” data over time. A “trend” is an upwards or downwards shift in a data set over time.

# %%
sn.lineplot(x='Event count',y='Total users',data=Event,color='r')
plt.title('Event Trend')
plt.xlabel('Event count')
plt.ylabel('Total users')
plt.show()

# %% [markdown]
# # Conversion Report
# Conversion report is the number of conversions that occur during a certain period of time.

# %%
#4
Conversion.head(10)
# Out:
#                          Event name  Conversions  Total users  Total revenue
# 0              notification_receive        94890         1311              0
# 1                     session_start        56203        21674              0
# 2                        first_open        22872        23059              0
# 3                        app_remove        12468        12538              0
# 4             Promilo111_otp_screen         1738          855              0
# 5  Promilo111_Event_Enter_Feed_Page         1594          969              0
# 6                  Promilo106_login         1458          603              0
# 7                  Promilo106_feeds          683          185              0
# 8                         os_update          672          634              0
# 9                 notification_open          569          308              0

# %%
Conversion.isnull().sum()
# Out:
# Event name       0
# Conversions      0
# Total users      0
# Total revenue    0
# dtype: int64

# %%
Conversion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Event name     18 non-null     object
#  1   Conversions    18 non-null     int64
#  2   Total users    18 non-null     int64
#  3   Total revenue  18 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 704.0+ bytes

# %%
# Assuming 'Conversion' is your DataFrame
sn.barplot(data=Conversion, x='Conversions', y='Total users')
plt.title('Conversions of total user')
plt.show()

# %% [markdown]
# #Page and Screen Report
# Page and Screen report is the number of page and screen that occur during a certain period of time.

# %%
#5
Page_screen.head(10)
# Out:
#   Page path and screen class   Views  Users  Views per user  \
# 0                    Flutter  156708   8726       17.958740
# 1               MainActivity   44326   8978        4.937180
# 2                      feeds   18514   4358        4.248279
# 3                      login   16883   7291        2.315595
# 4          my_rewards_screen   15381   2045        7.521271
# 5                 storyboard    8189   5244        1.561594
# 6          SignInHubActivity    6650   3778        1.760191
# 7        registration_screen    5501   3566        1.542625
# 8                feedDetails    3971   1047        3.792741
# 9                 otp_screen    3291   1678        1.961263
#
#    Average engagement time  Event count  Conversions  Total revenue
# 0                83.412220       203901          328              0
# 1                78.292160        53374          101              0
# 2                61.600050        37628          253              0
# ...

# %%
Page_screen.isnull().sum()
# Out:
# Page path and screen class    0
# Views                         0
# Users                         0
# Views per user                0
# Average engagement time       0
# Event count                   0
# Conversions                   0
# Total revenue                 0
# dtype: int64

# %%
Page_screen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Page path and screen class  42 non-null     object
#  1   Views                       42 non-null     int64
#  2   Users                       42 non-null     int64
#  3   Views per user              42 non-null     float64
#  4   Average engagement time     42 non-null     float64
#  5   Event count                 42 non-null     int64
#  6   Conversions                 42 non-null     int64
#  7   Total revenue               42 non-null     int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.8+ KB

# %%
# Top 10 pages and screens report
Page_screen_sort = Page_screen.sort_values(by="Views",ascending=False)
top10_pages_and_screens=Page_screen_sort.head(10)
top10_pages_and_screens

bar1=go.Bar(x=top10_pages_and_screens["Page path and screen class"],
            y=top10_pages_and_screens["Views"],
            text=top10_pages_and_screens["Views"],
            textposition="auto",
            name="Views",
            marker=dict(color="purple"))

layout = go.Layout(title="Top 10 pages and screens by views", height=600,
                   xaxis=dict(title='pages path and screen'),
                   yaxis=dict(title='Number of views'))
fig=go.Figure(data=[bar1],layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Below 10 pages and screens

Page_screen_sort = Page_screen.sort_values(by="Views",ascending=True)
top10_pages_and_screens=Page_screen_sort.head(10)
top10_pages_and_screens

bar1=go.Bar(x=top10_pages_and_screens["Page path and screen class"],
            y=top10_pages_and_screens["Views"],
            text=top10_pages_and_screens["Views"],
            textposition="auto",
            name="Views",
            marker=dict(color="Red"))

layout = go.Layout(title="Below 10 pages and screens by views", height=600,
                   xaxis=dict(title='pages path and screen'),
                   yaxis=dict(title='Number of views'))
fig=go.Figure(data=[bar1],layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Demographic Report

# %%
#6
Demographic.head(10)
# Out:
#           Country  Users  New users  Engaged sessions  Engagement rate  \
# 0           India  23024      22528             41479         0.593626
# 1   United States    272        213               197         0.491272
# 2          Canada     37         18                25         0.416667
# 3       (not set)     36         36                17         0.459459
# 4  United Kingdom     20          8                13         0.371429
# 5       Singapore     17          6                13         0.419355
# 6           Japan     11          6                11         0.550000
# 7       Australia     10          7                 8         0.500000
# 8      Bangladesh      7          2                10         0.625000
# 9         Germany      7          2                 6         0.500000
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.801555                334.81660      1312097
# ...

# %%
Demographic.isnull().sum()
# Out:
# Country                      0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
Demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    47 non-null     object
#  1   Users                      47 non-null     int64
#  2   New users                  47 non-null     int64
#  3   Engaged sessions           47 non-null     int64
#  4   Engagement rate            47 non-null     float64
#  5   Engaged sessions per user  47 non-null     float64
#  6   Average engagement time    47 non-null     float64
#  7   Event count                47 non-null     int64
#  8   Conversions                47 non-null     int64
#  9   Total revenue              47 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 3.8+ KB

# %%
demographic_sort=Demographic.sort_values(by=["Users","New users"],ascending=False)
top10_demographic=Demographic.head(10)
top10_demographic

bar1=go.Bar(x=top10_demographic["Country"],
            y=top10_demographic["Users"],
            text=top10_demographic["Users"],
            textposition="auto",
            name="Users",
            marker=dict(color="teal"))


bar2=go.Bar(x=top10_demographic["Country"],
            y=top10_demographic["New users"],
            text=top10_demographic["New users"],
            textposition="auto",
            name="New users",
            marker=dict(color="salmon"))

layout = go.Layout(title="Top 10 country who install application ", height=600,
                   xaxis=dict(title='Country'),
                   yaxis=dict(title='Number of users / new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #citiwise report

# %%
#7
Citiwise.head(10)
# Out:
#     Town/City  Users  New users  Engaged sessions  Engagement rate  \
# 0   Bengaluru   6097       5685             15013         0.769385
# 1       Patna   1594       1467              2127         0.440646
# 2   Hyderabad   1038        920              1578         0.569264
# 3      Indore    983        915              1241         0.426460
# 4     Lucknow    897        839              1125         0.450180
# 5      Mysuru    809        585              1220         0.630491
# 6     Chennai    798        631              1910         0.706361
# 7   (not set)    767        536               777         0.530014
# 8  Coimbatore    749        596              1412         0.635178
# 9    Guwahati    745        700               902         0.435959
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   2.462359                762.20550       607200
# 1                   1.334379                 98.22208        38830
# ...

# %%
Citiwise.isnull().sum()
# Out:
# Town/City                    0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
Citiwise.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Town/City                  574 non-null    object
#  1   Users                      574 non-null    int64
#  2   New users                  574 non-null    int64
#  3   Engaged sessions           574 non-null    int64
#  4   Engagement rate            574 non-null    float64
#  5   Engaged sessions per user  574 non-null    float64
#  6   Average engagement time    574 non-null    float64
#  7   Event count                574 non-null    int64
#  8   Conversions                574 non-null    int64
#  9   Total revenue              574 non-null    int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 45.0+ KB

# %%
#Top 10 cities attract users

citiwise_report_sort=Citiwise.sort_values(by=["Users","New users"],ascending =False)
top10_citi = citiwise_report_sort.head(10)
top10_citi

bar1=go.Bar(x=top10_citi["Town/City"],
            y=top10_citi["Users"],
            text=top10_citi["Users"],
            textposition="auto",
            name="Users",
            marker=dict(color="teal"))

bar2=go.Bar(x=top10_citi["Town/City"],
            y=top10_citi["New users"],
            text=top10_citi["New users"],
            textposition="auto",
            name="New users",
            marker=dict(color="salmon"))

layout = go.Layout(title="Top 10 cities attarct users", height=600,
                   xaxis=dict(title='Town/city'),
                   yaxis=dict(title='Number of users / new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Gender Report

# %%
#8
Gender
# Out:
#     Gender  Users  New users  Engaged sessions  Engagement rate  \
# 0  unknown  13142      12691             23161         0.564077
# 1     male   7218       5877             10467         0.543091
# 2   female   4944       4304              7877         0.637710
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.762365                 439.5776       761771
# 1                   1.450125                 128.2319       282504
# 2                   1.593244                 208.7407       274254
#
#    Conversions  Total revenue
# 0        93180              0
# 1        65651              0
# 2        35083              0

# %%
Gender.isnull().sum(),Gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Gender                     3 non-null      object
#  1   Users                      3 non-null      int64
#  2   New users                  3 non-null      int64
#  3   Engaged sessions           3 non-null      int64
#  4   Engagement rate            3 non-null      float64
#  5   Engaged sessions per user  3 non-null      float64
#  6   Average engagement time    3 non-null      float64
#  7   Event count                3 non-null      int64
#  8   Conversions                3 non-null      int64
#  9   Total revenue              3 non-null      int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 368.0+ bytes
# (Gender                       0
#  Users                        0
#  New users                    0
#  Engaged sessions             0
# ...

# %%
#Gender wise user percentage
pie_chart = go.Pie(labels=Gender["Gender"],
                   values=Gender["Users"],
                   marker=dict(colors=["red","Olive","teal"]),
                   textinfo='label+percent',
                   textposition='inside',
                   hoverinfo='label+percent',
                   hole=0.5)
layout = go.Layout(title='User gender wise percentage ')

fig = go.Figure(data=[pie_chart], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#9
Used_by_interest.head(10)
# Out:
#                                        Interests  Users  New users  \
# 0                                       Shoppers  10950       9256
# 1  Media & Entertainment/Comics & Animation Fans  10946       9247
# 2                  Technology/Mobile Enthusiasts  10934       9239
# 3              Food & Dining/Cooking Enthusiasts   8410       6970
# 4        Sports & Fitness/Health & Fitness Buffs   5844       4580
# 5                Lifestyles & Hobbies/Pet Lovers   5785       4768
# 6             Media & Entertainment/Music Lovers   5488       4504
# 7                Media & Entertainment/TV Lovers   5363       4312
# 8              News & Politics/Avid News Readers   5352       4110
# 9       Lifestyles & Hobbies/Outdoor Enthusiasts   5247       4271
#
#    Engaged sessions  Engagement rate  Engaged sessions per user  \
# 0             15652         0.581534                   1.429406
# 1             15680         0.583008                   1.432487
# ...

# %%
Used_by_interest.isnull().sum()
# Out:
# Interests                    0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
Used_by_interest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Interests                  89 non-null     object
#  1   Users                      89 non-null     int64
#  2   New users                  89 non-null     int64
#  3   Engaged sessions           89 non-null     int64
#  4   Engagement rate            89 non-null     float64
#  5   Engaged sessions per user  89 non-null     float64
#  6   Average engagement time    89 non-null     float64
#  7   Event count                89 non-null     int64
#  8   Conversions                89 non-null     int64
#  9   Total revenue              89 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 7.1+ KB

# %%
# Top 10 User intrest
used_by_intrest_sort=Used_by_interest.sort_values(by=["Users","New users"],ascending=False)
top10_userby_intrest=used_by_intrest_sort.head(10)
top10_userby_intrest

bar1=go.Bar(x=top10_userby_intrest["Interests"],
            y=top10_userby_intrest["Users"],
            text=top10_userby_intrest["Users"],
            textposition="auto",
            name="Users",
            marker=dict(color="teal"))


bar2=go.Bar(x=top10_userby_intrest["Interests"],
            y=top10_userby_intrest["New users"],
            text=top10_userby_intrest["New users"],
            textposition="auto",
            name="New users",
            marker=dict(color="salmon"))

layout = go.Layout(title="Top 10 Intrest users and user users attract ", height=600,
                   xaxis=dict(title='Intrest'),
                   yaxis=dict(title='Number of users / new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Language Report

# %%
#10
Language.head(10)
# Out:
#     Language  Users  New users  Engaged sessions  Engagement rate  \
# 0    English  22495      21990             40639         0.595147
# 1      Hindi    586        552               798         0.406314
# 2    Marathi     85         84                98         0.426087
# 3   Gujarati     78         77               100         0.448430
# 4     Telugu     43         42                56         0.455285
# 5      Tamil     36         36                43         0.518072
# 6  Malayalam     17         15                36         0.654545
# 7    Bengali     14         11                18         0.600000
# 8    Chinese     13         13                13         1.000000
# 9    Kannada     13         12                31         0.500000
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.806579                341.36350      1297970
# 1                   1.361775                 60.03413        13523
# ...

# %%
Language.isnull().sum()
# Out:
# Language                     0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
Language.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Language                   24 non-null     object
#  1   Users                      24 non-null     int64
#  2   New users                  24 non-null     int64
#  3   Engaged sessions           24 non-null     int64
#  4   Engagement rate            24 non-null     float64
#  5   Engaged sessions per user  24 non-null     float64
#  6   Average engagement time    24 non-null     float64
#  7   Event count                24 non-null     int64
#  8   Conversions                24 non-null     int64
#  9   Total revenue              24 non-null     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 2.0+ KB

# %%
# Top 10 Language prefrence
user_by_language_10 = Language.sort_values(by=["Users","New users"],ascending =False)

top_10_language=user_by_language_10.head(10)

bar1=go.Bar(x=top_10_language["Language"],
             y=top_10_language["Users"],
              text=top_10_language["Users"],
             textposition="auto",
             name="Users",
             marker=dict(color='teal'))
bar2=go.Bar(x=top_10_language["Language"],
             y=top_10_language["New users"],
                   text=top_10_language["New users"],
                   textposition="auto",
             name="New Users",
             marker=dict(color='salmon'))


layout = go.Layout(title="Top 10 language prefrences by users and new users ", height=600,
                   xaxis=dict(title='Languages'),
                   yaxis=dict(title='Number of users / new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()

# Top prefrences language was english
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#11
Use_by_age.head(10)
# Out:
#        Age  Users  New users  Engaged sessions  Engagement rate  \
# 0  unknown  14303      13636             24976         0.569098
# 1    18-24   4282       3678              7291         0.695308
# 2    25-34   2920       2161              3749         0.504780
# 3      65+   1422       1081              1640         0.539829
# 4    55-64   1403        979              1552         0.519411
# 5    35-44   1202        785              1420         0.510424
# 6    45-54    810        552               881         0.561862
#
#    Engaged sessions per user  Average engagement time  Event count  \
# 0                   1.746207                422.22330       817501
# 1                   1.702709                251.16300       309328
# 2                   1.283904                 97.24144        90074
# 3                   1.153305                 52.30661        24780
# 4                   1.106201                 55.37063        25169
# ...

# %%
Use_by_age.isnull().sum()
# Out:
# Age                          0
# Users                        0
# New users                    0
# Engaged sessions             0
# Engagement rate              0
# Engaged sessions per user    0
# Average engagement time      0
# Event count                  0
# Conversions                  0
# Total revenue                0
# dtype: int64

# %%
Use_by_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        7 non-null      object
#  1   Users                      7 non-null      int64
#  2   New users                  7 non-null      int64
#  3   Engaged sessions           7 non-null      int64
#  4   Engagement rate            7 non-null      float64
#  5   Engaged sessions per user  7 non-null      float64
#  6   Average engagement time    7 non-null      float64
#  7   Event count                7 non-null      int64
#  8   Conversions                7 non-null      int64
#  9   Total revenue              7 non-null      int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 688.0+ bytes

# %%
bar1 = go.Bar(x=Use_by_age['Age'],
              y=Use_by_age["Users"],
              text=Use_by_age["Users"],
              textposition="auto",
              name="Users",
              marker=dict(color='teal'))

bar2 = go.Bar(x=Use_by_age['Age'],
              y=Use_by_age["New users"],
              text=Use_by_age["New users"],
              textposition="auto",
              name="New Users",
              marker=dict(color='salmon'))


layout = go.Layout(title="Age wise users and new users", height=600,
                   xaxis=dict(title='Age Catergory'),
                   yaxis=dict(title='Number of unsers and new users'))
fig=go.Figure(data=[bar1,bar2],layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Google Ads Report

# %%
#12
Google_ads.head(10)
# Out:
#                   Session Google Ads campaign  Users  Sessions  \
# 0           App Installation for May --Shahid   5429     10936
# 1         App Install-States-A200Inst-20Jun22    842      1655
# 2     App Install-States-B100Installs-22Jun22    742      1332
# 3             App Install for April -- Shahid    473       976
# 4     Video-AppInstall-PS-Internships-11Jul22    510       966
# 5                         App promotion-App-3    732       945
# 6    App Instal-States-B200 &A100Inst-22Jun22    373       742
# 7        App Install-1to5NC-StateA200-07Jul22    370       610
# 8  App Instal-6to10NC-States-A200Inst-07Jul22    242       432
# 9        Video-AppInstall-PS-Browsing-11Jul22     91       188
#
#    Engaged sessions  Google Ads clicks  Google Ads cost  \
# 0              6276             147100       179175.000
# 1               968              28742        24309.130
# 2               780              17809        22374.580
# ...

# %%
Google_ads.isnull().sum()
# Out:
# Session Google Ads campaign    0
# Users                          0
# Sessions                       0
# Engaged sessions               0
# Google Ads clicks              0
# Google Ads cost                0
# Google Ads cost per click      0
# Conversions                    0
# Cost per conversion            0
# Event count                    0
# Total revenue                  0
# Return on ad spend             0
# dtype: int64

# %%
Google_ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Session Google Ads campaign  15 non-null     object
#  1   Users                        15 non-null     int64
#  2   Sessions                     15 non-null     int64
#  3   Engaged sessions             15 non-null     int64
#  4   Google Ads clicks            15 non-null     int64
#  5   Google Ads cost              15 non-null     float64
#  6   Google Ads cost per click    15 non-null     float64
#  7   Conversions                  15 non-null     int64
#  8   Cost per conversion          15 non-null     float64
#  9   Event count                  15 non-null     int64
#  10  Total revenue                15 non-null     int64
#  11  Return on ad spend           15 non-null     int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1.5+ KB

# %%
#users
user_graph =px.bar(Google_ads,x='Session Google Ads campaign',y='Users',
                    text_auto = True,height=500 )
user_graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Cost invested in google ads against return as a event count
line1 = go.Scatter(x=Google_ads["Session Google Ads campaign"],
                   y=Google_ads["Google Ads cost"],
                   mode="lines+markers",
                   text=Google_ads["Google Ads cost"],
                   marker=dict(color="teal"),
                   name="Google Ads cost")

line2 = go.Scatter(x=Google_ads["Session Google Ads campaign"],
                   y=Google_ads["Conversions"],
                   mode="lines + markers",
                   text=Google_ads["Conversions"],
                   marker=dict(color="salmon"),
                   name="Conversions")

layout = go.Layout(title="Cost invested in google add againsts conversion", height=600,
                   xaxis=dict(title='sessions google ads campaign'),
                   yaxis=dict(title='Amount invested and number of conversion'))
fig=go.Figure(data=[line1,line2],layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
